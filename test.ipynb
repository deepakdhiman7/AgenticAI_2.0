# %%
import requests
import json

# %%
url = "https://api.dify.ai/v1/workflows/04836c1f-5a14-4b82-a181-6ecee1592af8/run"

headers = {
    "Authorization": "Bearer app-Ph61UeI0CADlpmhL3cpbYyQr",
    "Content-Type": "application/json"
}

payload = {
    "inputs": {"user_query":"who is sachin tendulkar?"},
    # "response_mode": "streaming",
    "user": "abc-123"
}

response = requests.post(
    url,
    headers=headers,
    json=payload
)

print(response.status_code)
print(response.text)
# Out:
# 200
# ...

# %%
result = json.loads(response.text)

# %%
print(result['data']['outputs']['result'])
# Out:
# Sachin Ramesh Tendulkar (born 24 April 1973) is a former Indian international cricketer widely regarded as one of the greatest batsmen in cricket history.
#
# Key facts
# - International career: 1989–2013 (debut as a 16-year-old).
# - Style: Right-handed opening/middle-order batsman.
# - Major records: 100 international centuries (most by any player) and a total of 34,357 international runs (the highest aggregate in international cricket). He scored 15,921 Test runs and 18,426 ODI runs.
# - Milestones: First male cricketer to score a double century (200*) in a One Day International (2010).
# - Honors: Bharat Ratna (India’s highest civilian award, 2014), Padma Vibhushan (2008), Padma Shri (1999), Rajiv Gandhi Khel Ratna (1997–98), plus many cricketing awards.
# - Other roles: After retirement he has been involved in cricket mentoring, philanthropy and was a nominated member of India’s Rajya Sabha.
#
# ...
